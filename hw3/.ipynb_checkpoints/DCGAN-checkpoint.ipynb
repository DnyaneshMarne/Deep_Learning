# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import numpy as np
import torch.optim as optim
from torch.utils.data import DataLoader

# %%
#device setup
device = 'cuda:0' if torch.cuda.is_available() else 'cpu'

# %%
#set up seed for consistancy
torch.manual_seed(1)
#hyperparameters based on slides
learning_rate = 2e-4
batch_size = 128
image_size = 64
#black and white 1 for color img 3(r.g.b)
image_channels = 3
noise_dimension = 100
epochs = 50
discriminator_features = 64
generator_features = 64
adam_beta = 0.5
#get Cifar10 dataset
workers = 2
transforms = transforms.Compose(
    [
        transforms.Resize(image_size),
        transforms.ToTensor(),
        transforms.Normalize(
            [0.5 for _ in range(image_channels)], [0.5 for _ in range(image_channels)]
        ),
    ]
)
data_train = torchvision.datasets.CIFAR10(root='./DL HW 3/data', 
                                           train=True, 
                                           transform=transforms,  
                                           download=True)

train_loader = torch.utils.data.DataLoader(data_train, batch_size=batch_size,
                                          shuffle=True,num_workers=workers)
# Out:
# Files already downloaded and verified

# %%
class Discriminator(nn.Module):
    def __init__(self, channels_img, features_d):
        super(Discriminator, self).__init__()
        self.discrim = nn.Sequential(
            nn.Conv2d(
                channels_img, features_d, kernel_size=4, stride=2, padding=1
            ),
            nn.LeakyReLU(0.2),
            self._descrimStructure(features_d, features_d * 2, 4, 2, 1),
            self._descrimStructure(features_d * 2, features_d * 4, 4, 2, 1),
            self._descrimStructure(features_d * 4, features_d * 8, 4, 2, 1),
            nn.Conv2d(features_d * 8, 1, kernel_size=4, stride=2, padding=0),
            nn.Sigmoid(),
        )

    def _descrimStructure(self, in_channels, out_channels, kernel_size, stride, padding):
        return nn.Sequential(
            nn.Conv2d(
                in_channels,
                out_channels,
                kernel_size,
                stride,
                padding,
                bias=False,
            ),
            nn.LeakyReLU(0.2),
        )

    def forward(self, x):
        return self.discrim(x)


class Generator(nn.Module):
    def __init__(self, channels_noise, channels_img, features_g):
        super(Generator, self).__init__()
        self.genet = nn.Sequential(
            self._genetStructure(channels_noise, features_g * 16, 4, 1, 0),  # img: 4x4
            self._genetStructure(features_g * 16, features_g * 8, 4, 2, 1),  # img: 8x8
            self._genetStructure(features_g * 8, features_g * 4, 4, 2, 1),  # img: 16x16
            self._genetStructure(features_g * 4, features_g * 2, 4, 2, 1),  # img: 32x32
            nn.ConvTranspose2d(
                features_g * 2, channels_img, kernel_size=4, stride=2, padding=1
            ),
            nn.Tanh(),
        )

    def _genetStructure(self, in_channels, out_channels, kernel_size, stride, padding):
        return nn.Sequential(
            nn.ConvTranspose2d(
                in_channels,
                out_channels,
                kernel_size,
                stride,
                padding,
                bias=False,
            ),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(),
        )

    def forward(self, x):
        return self.genet(x)

# %%
def model_weights(model):
    # Initializes weights according to the DCGAN paper
    for m in model.modules():
        if isinstance(m, (nn.Conv2d, nn.ConvTranspose2d, nn.BatchNorm2d)):
            nn.init.normal_(m.weight.data, 0.0, 0.02)

# %%
genet = Generator(noise_dimension, image_channels, generator_features).to(device)
discrim = Discriminator(image_channels, discriminator_features).to(device)
model_weights(genet)
model_weights(discrim)

opt_gen = optim.Adam(genet.parameters(), lr=learning_rate, betas=(0.5,0.999))
opt_disc = optim.Adam(discrim.parameters(), lr=learning_rate, betas=(0.5,0.999))
criterion = nn.BCELoss()

fixed_noise = torch.randn(10, noise_dimension, 1, 1).to(device)
step = 0
loss_ge = []
loss_de = []
genet.train()
discrim.train()
fakeimg_list=[]
img_list=[]
for epoch in range(epochs):
    for batch_idx, (real, _) in enumerate(train_loader):
        real = real.to(device)
        noise = torch.randn(batch_size, noise_dimension, 1, 1).to(device)
        fake = genet(noise)

        disc_real = discrim(real).reshape(-1)
        loss_disc_real = criterion(disc_real, torch.ones_like(disc_real))
        disc_fake = discrim(fake.detach()).reshape(-1)
        loss_disc_fake = criterion(disc_fake, torch.zeros_like(disc_fake))
        loss_disc = (loss_disc_real + loss_disc_fake) / 2
        discrim.zero_grad()
        loss_de.append(loss_disc.detach().cpu())
        loss_disc.backward()
        opt_disc.step()
        output = discrim(fake).reshape(-1)
        loss_gen = criterion(output, torch.ones_like(output))
        loss_ge.append(loss_gen.detach().cpu())
        genet.zero_grad()
        loss_gen.backward()
        opt_gen.step()
        if batch_idx % 100 == 0:
            print(
                f"Epoch [{epoch}/{epochs}] Batch {batch_idx}/{len(train_loader)} \
                  Loss D: {loss_disc:.4f}, loss G: {loss_gen:.4f}"
            )

            with torch.no_grad():
                fak = genet(fixed_noise).detach().cpu()
                realI = real.detach().cpu()
                fakeimg_list.append(torchvision.utils.make_grid(fak, padding=2, normalize=True))
                img_list.append(torchvision.utils.make_grid(realI, padding=2, normalize=True))

            step += 1
# Out:
# Epoch [0/60] Batch 0/391                   Loss D: 0.6940, loss G: 0.7000
# Epoch [0/60] Batch 100/391                   Loss D: 0.0833, loss G: 3.2738
# Epoch [0/60] Batch 200/391                   Loss D: 0.1695, loss G: 2.5995
# Epoch [0/60] Batch 300/391                   Loss D: 0.3060, loss G: 1.8589
# Epoch [1/60] Batch 0/391                   Loss D: 0.4146, loss G: 1.9592
# Epoch [1/60] Batch 100/391                   Loss D: 0.6024, loss G: 1.4345
# Epoch [1/60] Batch 200/391                   Loss D: 0.4174, loss G: 1.4486
# Epoch [1/60] Batch 300/391                   Loss D: 0.5123, loss G: 1.0434
# Epoch [2/60] Batch 0/391                   Loss D: 0.5956, loss G: 1.1956
# Epoch [2/60] Batch 100/391                   Loss D: 0.5924, loss G: 1.1394
# Epoch [2/60] Batch 200/391                   Loss D: 0.5956, loss G: 1.2465
# Epoch [2/60] Batch 300/391                   Loss D: 0.5023, loss G: 1.2726
# Epoch [3/60] Batch 0/391                   Loss D: 0.6077, loss G: 1.3327
# Epoch [3/60] Batch 100/391                   Loss D: 0.4661, loss G: 1.1675
# Epoch [3/60] Batch 200/391                   Loss D: 0.3812, loss G: 1.4288
# Epoch [3/60] Batch 300/391                   Loss D: 0.6856, loss G: 2.0093
# Epoch [4/60] Batch 0/391                   Loss D: 0.4643, loss G: 1.4583
# Epoch [4/60] Batch 100/391                   Loss D: 0.5568, loss G: 2.3565
# Epoch [4/60] Batch 200/391                   Loss D: 0.5772, loss G: 2.7062
# Epoch [4/60] Batch 300/391                   Loss D: 0.4872, loss G: 1.5310
# Epoch [5/60] Batch 0/391                   Loss D: 0.7779, loss G: 1.2144
# Epoch [5/60] Batch 100/391                   Loss D: 0.5796, loss G: 1.1380
# Epoch [5/60] Batch 200/391                   Loss D: 0.5767, loss G: 1.1184
# Epoch [5/60] Batch 300/391                   Loss D: 0.6208, loss G: 1.2551
# Epoch [6/60] Batch 0/391                   Loss D: 0.5969, loss G: 1.1640
# Epoch [6/60] Batch 100/391                   Loss D: 0.6332, loss G: 1.0376
# Epoch [6/60] Batch 200/391                   Loss D: 0.5090, loss G: 1.3326
# Epoch [6/60] Batch 300/391                   Loss D: 0.4773, loss G: 1.3497
# Epoch [7/60] Batch 0/391                   Loss D: 0.6097, loss G: 1.1531
# Epoch [7/60] Batch 100/391                   Loss D: 0.6204, loss G: 1.5951
# Epoch [7/60] Batch 200/391                   Loss D: 0.6033, loss G: 2.4512
# Epoch [7/60] Batch 300/391                   Loss D: 0.6046, loss G: 1.1730
# Epoch [8/60] Batch 0/391                   Loss D: 0.4808, loss G: 1.4003
# Epoch [8/60] Batch 100/391                   Loss D: 0.5246, loss G: 1.2484
# Epoch [8/60] Batch 200/391                   Loss D: 0.6216, loss G: 1.1867
# Epoch [8/60] Batch 300/391                   Loss D: 0.6750, loss G: 1.2390
# Epoch [9/60] Batch 0/391                   Loss D: 0.5488, loss G: 1.0445
# Epoch [9/60] Batch 100/391                   Loss D: 0.5932, loss G: 1.1066
# Epoch [9/60] Batch 200/391                   Loss D: 0.6817, loss G: 1.6643
# Epoch [9/60] Batch 300/391                   Loss D: 0.5723, loss G: 1.0444
# Epoch [10/60] Batch 0/391                   Loss D: 0.6149, loss G: 1.3366
# Epoch [10/60] Batch 100/391                   Loss D: 0.6098, loss G: 0.9141
# Epoch [10/60] Batch 200/391                   Loss D: 0.5736, loss G: 1.0708
# Epoch [10/60] Batch 300/391                   Loss D: 0.6085, loss G: 1.0603
# Epoch [11/60] Batch 0/391                   Loss D: 0.6137, loss G: 0.8549
# Epoch [11/60] Batch 100/391                   Loss D: 0.6287, loss G: 1.1625
# Epoch [11/60] Batch 200/391                   Loss D: 0.6022, loss G: 0.8453
# Epoch [11/60] Batch 300/391                   Loss D: 0.6218, loss G: 0.9055
# Epoch [12/60] Batch 0/391                   Loss D: 0.6079, loss G: 0.8185
# Epoch [12/60] Batch 100/391                   Loss D: 0.5751, loss G: 1.0410
# Epoch [12/60] Batch 200/391                   Loss D: 0.6195, loss G: 1.0254
# Epoch [12/60] Batch 300/391                   Loss D: 0.5379, loss G: 1.3222
# Epoch [13/60] Batch 0/391                   Loss D: 0.5973, loss G: 0.9367
# Epoch [13/60] Batch 100/391                   Loss D: 0.6512, loss G: 1.1343
# Epoch [13/60] Batch 200/391                   Loss D: 0.5674, loss G: 1.0368
# Epoch [13/60] Batch 300/391                   Loss D: 0.6108, loss G: 1.0351
# Epoch [14/60] Batch 0/391                   Loss D: 0.6214, loss G: 0.9976
# Epoch [14/60] Batch 100/391                   Loss D: 0.5904, loss G: 1.0579
# Epoch [14/60] Batch 200/391                   Loss D: 0.6120, loss G: 0.9289
# Epoch [14/60] Batch 300/391                   Loss D: 0.5801, loss G: 1.0481
# Epoch [15/60] Batch 0/391                   Loss D: 0.5462, loss G: 1.1798
# Epoch [15/60] Batch 100/391                   Loss D: 0.7379, loss G: 0.9050
# Epoch [15/60] Batch 200/391                   Loss D: 0.5851, loss G: 1.3730
# Epoch [15/60] Batch 300/391                   Loss D: 0.6631, loss G: 0.8482
# Epoch [16/60] Batch 0/391                   Loss D: 0.5601, loss G: 1.0781
# Epoch [16/60] Batch 100/391                   Loss D: 0.6793, loss G: 0.8159
# Epoch [16/60] Batch 200/391                   Loss D: 0.6661, loss G: 1.2355
# Epoch [16/60] Batch 300/391                   Loss D: 0.4831, loss G: 1.0629
# Epoch [17/60] Batch 0/391                   Loss D: 0.7153, loss G: 0.6443
# Epoch [17/60] Batch 100/391                   Loss D: 0.5830, loss G: 0.9412
# Epoch [17/60] Batch 200/391                   Loss D: 0.6760, loss G: 0.8439
# Epoch [17/60] Batch 300/391                   Loss D: 0.6113, loss G: 1.1655
# Epoch [18/60] Batch 0/391                   Loss D: 0.7587, loss G: 1.3418
# Epoch [18/60] Batch 100/391                   Loss D: 0.7267, loss G: 0.7927
# Epoch [18/60] Batch 200/391                   Loss D: 0.6537, loss G: 0.8634
# Epoch [18/60] Batch 300/391                   Loss D: 0.7412, loss G: 0.5294
# Epoch [19/60] Batch 0/391                   Loss D: 0.5749, loss G: 1.1011
# Epoch [19/60] Batch 100/391                   Loss D: 0.5561, loss G: 1.0656
# Epoch [19/60] Batch 200/391                   Loss D: 0.6969, loss G: 0.7772
# Epoch [19/60] Batch 300/391                   Loss D: 0.6772, loss G: 0.8775
# Epoch [20/60] Batch 0/391                   Loss D: 0.5301, loss G: 1.2520
# Epoch [20/60] Batch 100/391                   Loss D: 0.5177, loss G: 1.2560
# Epoch [20/60] Batch 200/391                   Loss D: 0.6903, loss G: 0.9261
# Epoch [20/60] Batch 300/391                   Loss D: 0.5924, loss G: 1.0028
# Epoch [21/60] Batch 0/391                   Loss D: 0.5926, loss G: 1.1803
# Epoch [21/60] Batch 100/391                   Loss D: 0.6591, loss G: 1.0316
# Epoch [21/60] Batch 200/391                   Loss D: 0.5234, loss G: 1.7775
# Epoch [21/60] Batch 300/391                   Loss D: 0.4848, loss G: 1.5177
# Epoch [22/60] Batch 0/391                   Loss D: 0.6306, loss G: 0.8777
# Epoch [22/60] Batch 100/391                   Loss D: 0.6135, loss G: 0.9730
# Epoch [22/60] Batch 200/391                   Loss D: 0.6676, loss G: 0.9920
# Epoch [22/60] Batch 300/391                   Loss D: 0.5961, loss G: 1.3986
# Epoch [23/60] Batch 0/391                   Loss D: 0.5618, loss G: 0.9170
# Epoch [23/60] Batch 100/391                   Loss D: 0.7534, loss G: 1.0417
# Epoch [23/60] Batch 200/391                   Loss D: 0.7481, loss G: 1.2323
# Epoch [23/60] Batch 300/391                   Loss D: 0.5159, loss G: 1.1542
# Epoch [24/60] Batch 0/391                   Loss D: 0.5996, loss G: 1.0453
# Epoch [24/60] Batch 100/391                   Loss D: 0.5915, loss G: 1.3922
# Epoch [24/60] Batch 200/391                   Loss D: 0.6105, loss G: 1.2179
# Epoch [24/60] Batch 300/391                   Loss D: 0.5630, loss G: 1.0875
# Epoch [25/60] Batch 0/391                   Loss D: 0.5931, loss G: 0.6526
# Epoch [25/60] Batch 100/391                   Loss D: 0.4958, loss G: 1.2809
# Epoch [25/60] Batch 200/391                   Loss D: 0.6471, loss G: 0.9085
# Epoch [25/60] Batch 300/391                   Loss D: 0.6513, loss G: 0.9766
# Epoch [26/60] Batch 0/391                   Loss D: 0.5765, loss G: 0.9475
# Epoch [26/60] Batch 100/391                   Loss D: 0.6056, loss G: 1.0046
# Epoch [26/60] Batch 200/391                   Loss D: 0.6694, loss G: 0.8817
# Epoch [26/60] Batch 300/391                   Loss D: 0.5667, loss G: 1.2571
# Epoch [27/60] Batch 0/391                   Loss D: 0.6393, loss G: 0.9971
# Epoch [27/60] Batch 100/391                   Loss D: 0.6830, loss G: 0.7685
# Epoch [27/60] Batch 200/391                   Loss D: 0.6315, loss G: 0.8762
# Epoch [27/60] Batch 300/391                   Loss D: 0.8378, loss G: 1.1917
# Epoch [28/60] Batch 0/391                   Loss D: 0.5943, loss G: 1.2651
# Epoch [28/60] Batch 100/391                   Loss D: 0.6048, loss G: 0.9430
# Epoch [28/60] Batch 200/391                   Loss D: 0.5104, loss G: 1.1891
# Epoch [28/60] Batch 300/391                   Loss D: 0.5604, loss G: 1.3481
# Epoch [29/60] Batch 0/391                   Loss D: 0.9735, loss G: 1.8322
# Epoch [29/60] Batch 100/391                   Loss D: 0.6217, loss G: 0.9685
# Epoch [29/60] Batch 200/391                   Loss D: 0.3053, loss G: 1.3433
# Epoch [29/60] Batch 300/391                   Loss D: 0.6358, loss G: 0.9638
# Epoch [30/60] Batch 0/391                   Loss D: 0.4371, loss G: 1.1352
# Epoch [30/60] Batch 100/391                   Loss D: 0.6205, loss G: 1.0550
# Epoch [30/60] Batch 200/391                   Loss D: 0.5632, loss G: 1.0068
# Epoch [30/60] Batch 300/391                   Loss D: 0.4940, loss G: 1.4495
# Epoch [31/60] Batch 0/391                   Loss D: 0.6118, loss G: 1.7414
# Epoch [31/60] Batch 100/391                   Loss D: 0.3932, loss G: 1.9764
# Epoch [31/60] Batch 200/391                   Loss D: 0.5545, loss G: 1.0991
# Epoch [31/60] Batch 300/391                   Loss D: 0.4874, loss G: 1.0207
# Epoch [32/60] Batch 0/391                   Loss D: 0.5093, loss G: 1.4991
# Epoch [32/60] Batch 100/391                   Loss D: 0.3876, loss G: 1.2907
# Epoch [32/60] Batch 200/391                   Loss D: 0.5784, loss G: 1.1950
# Epoch [32/60] Batch 300/391                   Loss D: 0.6406, loss G: 0.9175
# Epoch [33/60] Batch 0/391                   Loss D: 0.6293, loss G: 0.9374
# Epoch [33/60] Batch 100/391                   Loss D: 0.5896, loss G: 0.9777
# Epoch [33/60] Batch 200/391                   Loss D: 0.6617, loss G: 1.9208
# Epoch [33/60] Batch 300/391                   Loss D: 0.5518, loss G: 1.1450
# Epoch [34/60] Batch 0/391                   Loss D: 0.5965, loss G: 1.4253
# Epoch [34/60] Batch 100/391                   Loss D: 0.4652, loss G: 1.4485
# Epoch [34/60] Batch 200/391                   Loss D: 0.5365, loss G: 1.3808
# Epoch [34/60] Batch 300/391                   Loss D: 0.5936, loss G: 1.0346
# Epoch [35/60] Batch 0/391                   Loss D: 0.5818, loss G: 0.7707
# Epoch [35/60] Batch 100/391                   Loss D: 0.4717, loss G: 1.5840
# Epoch [35/60] Batch 200/391                   Loss D: 0.7681, loss G: 2.0909
# Epoch [35/60] Batch 300/391                   Loss D: 0.5576, loss G: 1.2145
# Epoch [36/60] Batch 0/391                   Loss D: 0.5596, loss G: 1.2625
# Epoch [36/60] Batch 100/391                   Loss D: 0.5836, loss G: 1.8761
# Epoch [36/60] Batch 200/391                   Loss D: 0.3439, loss G: 1.8245
# Epoch [36/60] Batch 300/391                   Loss D: 0.4097, loss G: 1.0114
# Epoch [37/60] Batch 0/391                   Loss D: 0.5059, loss G: 1.7079
# Epoch [37/60] Batch 100/391                   Loss D: 0.6411, loss G: 0.9864
# Epoch [37/60] Batch 200/391                   Loss D: 0.5784, loss G: 1.1227
# Epoch [37/60] Batch 300/391                   Loss D: 0.4682, loss G: 1.4679
# Epoch [38/60] Batch 0/391                   Loss D: 0.5412, loss G: 1.5311
# Epoch [38/60] Batch 100/391                   Loss D: 0.3963, loss G: 0.8788
# Epoch [38/60] Batch 200/391                   Loss D: 0.5420, loss G: 1.3192
# Epoch [38/60] Batch 300/391                   Loss D: 0.5498, loss G: 1.4871
# Epoch [39/60] Batch 0/391                   Loss D: 0.3275, loss G: 1.5337
# Epoch [39/60] Batch 100/391                   Loss D: 0.5223, loss G: 1.1451
# Epoch [39/60] Batch 200/391                   Loss D: 0.5073, loss G: 1.3085
# Epoch [39/60] Batch 300/391                   Loss D: 0.5316, loss G: 1.2716
# Epoch [40/60] Batch 0/391                   Loss D: 0.5113, loss G: 1.8502
# Epoch [40/60] Batch 100/391                   Loss D: 0.7786, loss G: 1.4695
# Epoch [40/60] Batch 200/391                   Loss D: 0.5206, loss G: 2.1298
# Epoch [40/60] Batch 300/391                   Loss D: 0.5078, loss G: 1.2285
# Epoch [41/60] Batch 0/391                   Loss D: 0.4392, loss G: 1.5578
# Epoch [41/60] Batch 100/391                   Loss D: 0.4921, loss G: 0.4386
# Epoch [41/60] Batch 200/391                   Loss D: 0.5267, loss G: 1.1915
# Epoch [41/60] Batch 300/391                   Loss D: 0.5134, loss G: 1.2465
# Epoch [42/60] Batch 0/391                   Loss D: 0.4906, loss G: 1.4449
# Epoch [42/60] Batch 100/391                   Loss D: 0.5718, loss G: 1.1494
# Epoch [42/60] Batch 200/391                   Loss D: 0.3769, loss G: 1.7103
# Epoch [42/60] Batch 300/391                   Loss D: 0.5144, loss G: 1.2312
# Epoch [43/60] Batch 0/391                   Loss D: 0.5220, loss G: 1.1283
# Epoch [43/60] Batch 100/391                   Loss D: 0.5532, loss G: 1.2382
# Epoch [43/60] Batch 200/391                   Loss D: 0.5185, loss G: 2.3454
# Epoch [43/60] Batch 300/391                   Loss D: 0.5182, loss G: 1.1637
# Epoch [44/60] Batch 0/391                   Loss D: 0.5623, loss G: 1.2700
# Epoch [44/60] Batch 100/391                   Loss D: 0.4959, loss G: 0.9859
# Epoch [44/60] Batch 200/391                   Loss D: 0.6000, loss G: 1.0616
# Epoch [44/60] Batch 300/391                   Loss D: 0.5045, loss G: 1.2113
# Epoch [45/60] Batch 0/391                   Loss D: 0.5160, loss G: 1.3269
# Epoch [45/60] Batch 100/391                   Loss D: 0.4377, loss G: 1.6601
# Epoch [45/60] Batch 200/391                   Loss D: 0.4235, loss G: 1.4387
# Epoch [45/60] Batch 300/391                   Loss D: 0.4789, loss G: 1.6401
# Epoch [46/60] Batch 0/391                   Loss D: 0.5313, loss G: 1.5527
# Epoch [46/60] Batch 100/391                   Loss D: 0.4303, loss G: 1.4872
# Epoch [46/60] Batch 200/391                   Loss D: 0.4585, loss G: 0.6416
# Epoch [46/60] Batch 300/391                   Loss D: 0.5685, loss G: 1.2173
# Epoch [47/60] Batch 0/391                   Loss D: 0.5509, loss G: 1.2245
# Epoch [47/60] Batch 100/391                   Loss D: 0.7059, loss G: 1.5239
# Epoch [47/60] Batch 200/391                   Loss D: 0.4569, loss G: 1.5485
# Epoch [47/60] Batch 300/391                   Loss D: 0.4258, loss G: 1.4635
# Epoch [48/60] Batch 0/391                   Loss D: 0.5009, loss G: 1.4454
# Epoch [48/60] Batch 100/391                   Loss D: 0.3945, loss G: 1.4477
# Epoch [48/60] Batch 200/391                   Loss D: 0.4009, loss G: 1.5102
# Epoch [48/60] Batch 300/391                   Loss D: 0.4292, loss G: 1.7846
# Epoch [49/60] Batch 0/391                   Loss D: 0.4806, loss G: 1.8253
# Epoch [49/60] Batch 100/391                   Loss D: 0.4092, loss G: 1.0654
# Epoch [49/60] Batch 200/391                   Loss D: 0.3216, loss G: 1.2856
# Epoch [49/60] Batch 300/391                   Loss D: 0.7251, loss G: 1.0875
# Epoch [50/60] Batch 0/391                   Loss D: 0.4289, loss G: 1.5225
# Epoch [50/60] Batch 100/391                   Loss D: 0.5154, loss G: 1.3973
# Epoch [50/60] Batch 200/391                   Loss D: 0.4073, loss G: 1.5502
# Epoch [50/60] Batch 300/391                   Loss D: 0.5071, loss G: 1.2563
# Epoch [51/60] Batch 0/391                   Loss D: 0.3211, loss G: 1.5405
# Epoch [51/60] Batch 100/391                   Loss D: 0.4812, loss G: 1.6569
# Epoch [51/60] Batch 200/391                   Loss D: 0.4553, loss G: 1.2492
# Epoch [51/60] Batch 300/391                   Loss D: 0.3028, loss G: 1.9167
# Epoch [52/60] Batch 0/391                   Loss D: 0.4574, loss G: 1.4364
# Epoch [52/60] Batch 100/391                   Loss D: 0.4723, loss G: 1.5386
# Epoch [52/60] Batch 200/391                   Loss D: 0.5518, loss G: 1.6497
# Epoch [52/60] Batch 300/391                   Loss D: 0.3799, loss G: 1.8026
# Epoch [53/60] Batch 0/391                   Loss D: 0.3851, loss G: 1.9214
# Epoch [53/60] Batch 100/391                   Loss D: 0.4165, loss G: 2.2006
# Epoch [53/60] Batch 200/391                   Loss D: 0.3626, loss G: 1.9320
# Epoch [53/60] Batch 300/391                   Loss D: 0.4923, loss G: 1.5538
# Epoch [54/60] Batch 0/391                   Loss D: 0.3741, loss G: 1.7786
# Epoch [54/60] Batch 100/391                   Loss D: 0.4462, loss G: 1.6867
# Epoch [54/60] Batch 200/391                   Loss D: 0.3352, loss G: 1.8122
# Epoch [54/60] Batch 300/391                   Loss D: 0.3307, loss G: 1.6064
# Epoch [55/60] Batch 0/391                   Loss D: 0.4109, loss G: 1.6963
# Epoch [55/60] Batch 100/391                   Loss D: 0.3432, loss G: 1.8649
# Epoch [55/60] Batch 200/391                   Loss D: 0.4897, loss G: 2.4096
# Epoch [55/60] Batch 300/391                   Loss D: 0.5189, loss G: 1.4188
# Epoch [56/60] Batch 0/391                   Loss D: 0.4741, loss G: 1.5376
# Epoch [56/60] Batch 100/391                   Loss D: 0.2174, loss G: 2.1390
# Epoch [56/60] Batch 200/391                   Loss D: 0.4104, loss G: 1.4840
# Epoch [56/60] Batch 300/391                   Loss D: 0.4437, loss G: 1.7536
# Epoch [57/60] Batch 0/391                   Loss D: 0.3921, loss G: 1.3625
# Epoch [57/60] Batch 100/391                   Loss D: 0.5129, loss G: 1.5350
# Epoch [57/60] Batch 200/391                   Loss D: 0.3442, loss G: 1.7040
# Epoch [57/60] Batch 300/391                   Loss D: 0.3544, loss G: 2.1284
# Epoch [58/60] Batch 0/391                   Loss D: 0.3532, loss G: 1.5673
# Epoch [58/60] Batch 100/391                   Loss D: 0.3554, loss G: 1.4715
# Epoch [58/60] Batch 200/391                   Loss D: 0.3780, loss G: 1.9703
# Epoch [58/60] Batch 300/391                   Loss D: 0.4071, loss G: 2.0735
# Epoch [59/60] Batch 0/391                   Loss D: 0.4351, loss G: 1.6169
# Epoch [59/60] Batch 100/391                   Loss D: 0.4273, loss G: 1.8232
# Epoch [59/60] Batch 200/391                   Loss D: 0.3557, loss G: 1.5868
# Epoch [59/60] Batch 300/391                   Loss D: 0.4573, loss G: 1.8473

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(8,8))
plt.axis("off")
plt.title('Noise Epoch 0')
ims = [[plt.imshow(np.transpose(i,(1,2,0)), animated=True)] for i in fakeimg_list[0:1]]

# %%
tr = fakeimg_list[0:30]
fig = plt.figure(figsize=(8,8))
plt.axis("off")
plt.title('Noise Epoch 30')
ims = [[plt.imshow(np.transpose(i,(1,2,0)), animated=True)] for i in tr]

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(8,8))
plt.axis("off")
plt.title('Final Epoch')
ims = [[plt.imshow(np.transpose(i,(1,2,0)), animated=True)] for i in fakeimg_list]

# %%
plt.title('Losses')
plt.plot(loss_ge,label = "generator loss")
plt.plot(loss_de,label = "descrimanator loss")
plt.legend()
